# %% [markdown]
# Dataset 2 : College and Universities in the US

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Colleges_and_Universities.csv")

df = df[["NAME","ADDRESS","STATE","ZIP","TYPE","COUNTY","LATITUDE","LONGITUDE","PT_ENROLL","FT_ENROLL","TOT_ENROLL","TOT_EMPLOY"]]
df
# Out:
#                                                NAME  \
# 0                                   Shorter College
# 1                     Citrus Heights Beauty College
# 2          Joe Blasco Makeup Artist Training Center
# 3                          Waynes College of Beauty
# 4                Hult International Business School
# ...                                             ...
# 7730  Connecticut Center for Massage Therapy-Groton
# 7731       Pierpont Community and Technical College
# 7732        Universal College of Beauty Inc-Compton
# 7733                 ITT Technical Institute-Duluth
# 7734               ITT Technical Institute-Hilliard
#
#                               ADDRESS STATE    ZIP  TYPE       COUNTY  \
# 0                       604 Locust St    AR  72114     2      Pulaski
# 1                      7518 Baird Way    CA  95610     3   Sacramento
# 2               1670 Hillhurst Avenue    CA  90027     3  Los Angeles
# ...

# %%
#1 = public
#2 = private non-profit
#3 = private for profit
def renameType(i):
    if(i==1):
        i= "public"
    elif(i==2):
        i = "private non-profit"
    elif(i==3):
        i = "private for profit"
    return i
    
df["TYPE"]=df["TYPE"].apply(renameType)
df["TYPE"]
# Out:
# 0       private non-profit
# 1       private for profit
# 2       private for profit
# 3       private for profit
# 4       private non-profit
#                ...
# 7730    private for profit
# 7731                public
# 7732    private for profit
# 7733    private for profit
# 7734    private for profit
# Name: TYPE, Length: 7735, dtype: object

# %%
#remove null
df=df.drop(df[df['TOT_ENROLL'] ==0].index)
df = df.drop(df[df["TOT_EMPLOY"]==0].index)
df
# Out:
#                                                NAME  \
# 0                                   Shorter College
# 1                     Citrus Heights Beauty College
# 2          Joe Blasco Makeup Artist Training Center
# 3                          Waynes College of Beauty
# 4                Hult International Business School
# ...                                             ...
# 7729         University of Phoenix-Charlotte Campus
# 7730  Connecticut Center for Massage Therapy-Groton
# 7731       Pierpont Community and Technical College
# 7733                 ITT Technical Institute-Duluth
# 7734               ITT Technical Institute-Hilliard
#
#                               ADDRESS STATE    ZIP                TYPE  \
# 0                       604 Locust St    AR  72114  private non-profit
# 1                      7518 Baird Way    CA  95610  private for profit
# 2               1670 Hillhurst Avenue    CA  90027  private for profit
# ...

# %%
df["EMPLOYEE/STUDENT RATIO"] = df["TOT_ENROLL"]/df["TOT_EMPLOY"]
df
# Out:
#                                                NAME  \
# 0                                   Shorter College
# 1                     Citrus Heights Beauty College
# 2          Joe Blasco Makeup Artist Training Center
# 3                          Waynes College of Beauty
# 4                Hult International Business School
# ...                                             ...
# 7729         University of Phoenix-Charlotte Campus
# 7730  Connecticut Center for Massage Therapy-Groton
# 7731       Pierpont Community and Technical College
# 7733                 ITT Technical Institute-Duluth
# 7734               ITT Technical Institute-Hilliard
#
#                               ADDRESS STATE    ZIP                TYPE  \
# 0                       604 Locust St    AR  72114  private non-profit
# 1                      7518 Baird Way    CA  95610  private for profit
# 2               1670 Hillhurst Avenue    CA  90027  private for profit
# ...

# %%
household_income = pd.read_csv("Median Household Income by State 1984 through 2015.csv")
household_income=household_income.drop(0)

household_income=household_income[["State","2014-2015"]]
household_income = household_income.rename({"State":"STATE"},axis=1)
household_income
# Out:
#                                                 STATE 2014-2015
# 1                                       United States    55,117
# 2                                             Alabama    43,418
# 3                                              Alaska    71,409
# 4                                             Arizona    50,779
# 5                                            Arkansas    43,886
# 6                                          California    62,096
# 7                                            Colorado    63,803
# 8                                         Connecticut    71,566
# 9                                            Delaware    57,672
# 10                                               D.C.    69,213
# 11                                            Florida    47,509
# 12                                            Georgia    50,190
# 13                                             Hawaii    67,909
# 14                                              Idaho    52,562
# ...

# %%
#drop first row
household_income = household_income.drop(household_income.index[0])
household_income
# Out:
#              STATE 2014-2015
# 2          Alabama    43,418
# 3           Alaska    71,409
# 4          Arizona    50,779
# 5         Arkansas    43,886
# 6       California    62,096
# 7         Colorado    63,803
# 8      Connecticut    71,566
# 9         Delaware    57,672
# 10            D.C.    69,213
# 11         Florida    47,509
# 12         Georgia    50,190
# 13          Hawaii    67,909
# 14           Idaho    52,562
# 15        Illinois    57,696
# 16         Indiana    50,049
# 17            Iowa    59,366
# 18          Kansas    54,185
# 19        Kentucky    42,611
# 20       Louisiana    44,189
# 21           Maine    51,263
# 22        Maryland    74,923
# 23   Massachusetts    65,542
# 24        Michigan    53,134
# 25       Minnesota    68,026
# 26     Mississippi    37,800
# 27        Missouri    57,946
# 28         Montana    51,278
# 29        Nebraska    58,705
# 30          Nevada    50,970
# 31   New Hampshire    74,579
# 32      New Jersey    66,838
# ...

# %%
#drop last 3 row
household_income = household_income.drop(household_income.index[-3:])
household_income.index[-3:]
# Out:
# Int64Index([50, 51, 52], dtype='int64')

# %%
for column in household_income:
    if household_income[column].dtypes == "object":
        household_income[column] = household_income[column].str.strip()
household_income
# Out:
#              STATE 2014-2015
# 2          Alabama    43,418
# 3           Alaska    71,409
# 4          Arizona    50,779
# 5         Arkansas    43,886
# 6       California    62,096
# 7         Colorado    63,803
# 8      Connecticut    71,566
# 9         Delaware    57,672
# 10            D.C.    69,213
# 11         Florida    47,509
# 12         Georgia    50,190
# 13          Hawaii    67,909
# 14           Idaho    52,562
# 15        Illinois    57,696
# 16         Indiana    50,049
# 17            Iowa    59,366
# 18          Kansas    54,185
# 19        Kentucky    42,611
# 20       Louisiana    44,189
# 21           Maine    51,263
# 22        Maryland    74,923
# 23   Massachusetts    65,542
# 24        Michigan    53,134
# 25       Minnesota    68,026
# 26     Mississippi    37,800
# 27        Missouri    57,946
# 28         Montana    51,278
# 29        Nebraska    58,705
# 30          Nevada    50,970
# 31   New Hampshire    74,579
# 32      New Jersey    66,838
# ...

# %%
def convertState(state):
    states_dict = {
    'AK': 'Alaska',
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'D.C.': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'ME': 'Maine',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MS': 'Mississippi',
    'MT': 'Montana',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'VT': 'Vermont',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'WY': 'Wyoming'
}
    for key in states_dict:
            if (state == states_dict[key]):
                return key
        
x = household_income["STATE"].apply(convertState)
x[10] = "DC"
x[3] = "AK"
household_income["STATE"] = x
household_income["STATE"]
# Out:
# 2     AL
# 3     AK
# 4     AZ
# 5     AR
# 6     CA
# 7     CO
# 8     CT
# 9     DE
# 10    DC
# 11    FL
# 12    GA
# 13    HI
# 14    ID
# 15    IL
# 16    IN
# 17    IA
# 18    KS
# 19    KY
# 20    LA
# 21    ME
# 22    MD
# 23    MA
# 24    MI
# 25    MN
# 26    MS
# 27    MO
# 28    MT
# 29    NE
# 30    NV
# 31    NH
# 32    NJ
# 33    NM
# 34    NY
# 35    NC
# 36    ND
# 37    OH
# 38    OK
# 39    OR
# 40    PA
# 41    RI
# 42    SC
# 43    SD
# 44    TN
# 45    TX
# 46    UT
# 47    VT
# 48    VA
# 49    WA
# 50    WV
# 51    WI
# 52    WY
# Name: STATE, dtype: object

# %%
for column in df:
    if df[column].dtypes == "object":
        df[column] = df[column].str.strip()
df
# Out:
#                                                NAME  \
# 0                                   Shorter College
# 1                     Citrus Heights Beauty College
# 2          Joe Blasco Makeup Artist Training Center
# 3                          Waynes College of Beauty
# 4                Hult International Business School
# ...                                             ...
# 7729         University of Phoenix-Charlotte Campus
# 7730  Connecticut Center for Massage Therapy-Groton
# 7731       Pierpont Community and Technical College
# 7733                 ITT Technical Institute-Duluth
# 7734               ITT Technical Institute-Hilliard
#
#                               ADDRESS STATE    ZIP                TYPE  \
# 0                       604 Locust St    AR  72114  private non-profit
# 1                      7518 Baird Way    CA  95610  private for profit
# 2               1670 Hillhurst Avenue    CA  90027  private for profit
# ...

# %%
mergeddf = pd.merge(df,household_income,on =["STATE"])
mergeddf
# Out:
#                                           NAME  \
# 0                              Shorter College
# 1        Regency Beauty Institute-Fayetteville
# 2             Salon Professional Academy (The)
# 3         Regency Beauty Institute-Little Rock
# 4                  Strayer University-Arkansas
# ...                                        ...
# 7267                          Sterling College
# 7268                 Vermont Technical College
# 7269                     University of Vermont
# 7270                          Landmark College
# 7271  The Salon Professional Academy-Williston
#
#                                   ADDRESS STATE    ZIP                TYPE  \
# 0                           604 Locust St    AR  72114  private non-profit
# 1                   4107 Steele Boulevard    AR  72703  private for profit
# 2           4619 John F Kennedy Boulevard    AR  72116  private for profit
# 3             2614 South Shackleford Road    AR  72205  private for profit
# ...

# %%
mergeddf=mergeddf.rename(columns={"2014-2015":"INCOME"})
mergeddf
# Out:
#                                           NAME  \
# 0                              Shorter College
# 1        Regency Beauty Institute-Fayetteville
# 2             Salon Professional Academy (The)
# 3         Regency Beauty Institute-Little Rock
# 4                  Strayer University-Arkansas
# ...                                        ...
# 7267                          Sterling College
# 7268                 Vermont Technical College
# 7269                     University of Vermont
# 7270                          Landmark College
# 7271  The Salon Professional Academy-Williston
#
#                                   ADDRESS STATE    ZIP                TYPE  \
# 0                           604 Locust St    AR  72114  private non-profit
# 1                   4107 Steele Boulevard    AR  72703  private for profit
# 2           4619 John F Kennedy Boulevard    AR  72116  private for profit
# 3             2614 South Shackleford Road    AR  72205  private for profit
# ...

# %%
mergeddf.to_csv("university_median_income.csv", index = False)

# %%
test = pd.read_csv("university_median_income.csv")
test
# Out:
#                                           NAME  \
# 0                              Shorter College
# 1        Regency Beauty Institute-Fayetteville
# 2             Salon Professional Academy (The)
# 3         Regency Beauty Institute-Little Rock
# 4                  Strayer University-Arkansas
# ...                                        ...
# 7267                          Sterling College
# 7268                 Vermont Technical College
# 7269                     University of Vermont
# 7270                          Landmark College
# 7271  The Salon Professional Academy-Williston
#
#                                   ADDRESS STATE    ZIP                TYPE  \
# 0                           604 Locust St    AR  72114  private non-profit
# 1                   4107 Steele Boulevard    AR  72703  private for profit
# 2           4619 John F Kennedy Boulevard    AR  72116  private for profit
# 3             2614 South Shackleford Road    AR  72205  private for profit
# ...

# %%
salaries = pd.read_csv("salaries-by-college-type.csv")
salaries
# Out:
#                                School Name  School Type  \
# 0    Massachusetts Institute of Technology  Engineering
# 1       California Institute of Technology  Engineering
# 2                      Harvey Mudd College  Engineering
# 3       Polytechnic University of New York  Engineering
# 4                             Cooper Union  Engineering
# ..                                     ...          ...
# 264           Austin Peay State University        State
# 265             Pittsburg State University        State
# 266               Southern Utah University        State
# 267      Montana State University Billings        State
# 268           Black Hills State University        State
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0               $72,200.00              $126,000.00
# 1               $75,500.00              $123,000.00
# 2               $71,800.00              $122,000.00
# 3               $62,400.00              $114,000.00
# ...

# %%
for column in salaries:
    if salaries[column].dtypes == "object":
        salaries[column] = salaries[column].str.strip()
salaries
# Out:
#                                School Name  School Type  \
# 0    Massachusetts Institute of Technology  Engineering
# 1       California Institute of Technology  Engineering
# 2                      Harvey Mudd College  Engineering
# 3       Polytechnic University of New York  Engineering
# 4                             Cooper Union  Engineering
# ..                                     ...          ...
# 264           Austin Peay State University        State
# 265             Pittsburg State University        State
# 266               Southern Utah University        State
# 267      Montana State University Billings        State
# 268           Black Hills State University        State
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0               $72,200.00              $126,000.00
# 1               $75,500.00              $123,000.00
# 2               $71,800.00              $122,000.00
# 3               $62,400.00              $114,000.00
# ...

# %%
salaries=salaries.rename(columns ={"School Name":"NAME"})
salaries
# Out:
#                                       NAME  School Type  \
# 0    Massachusetts Institute of Technology  Engineering
# 1       California Institute of Technology  Engineering
# 2                      Harvey Mudd College  Engineering
# 3       Polytechnic University of New York  Engineering
# 4                             Cooper Union  Engineering
# ..                                     ...          ...
# 264           Austin Peay State University        State
# 265             Pittsburg State University        State
# 266               Southern Utah University        State
# 267      Montana State University Billings        State
# 268           Black Hills State University        State
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0               $72,200.00              $126,000.00
# 1               $75,500.00              $123,000.00
# 2               $71,800.00              $122,000.00
# 3               $62,400.00              $114,000.00
# ...

# %%
mergeddf2 = pd.merge(salaries,test,on =["NAME"])
mergeddf2
# Out:
#                                       NAME  School Type  \
# 0    Massachusetts Institute of Technology  Engineering
# 1       California Institute of Technology  Engineering
# 2                      Harvey Mudd College  Engineering
# 3       Polytechnic University of New York  Engineering
# 4                             Cooper Union  Engineering
# ..                                     ...          ...
# 255           Austin Peay State University        State
# 256             Pittsburg State University        State
# 257               Southern Utah University        State
# 258      Montana State University Billings        State
# 259           Black Hills State University        State
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0               $72,200.00              $126,000.00
# 1               $75,500.00              $123,000.00
# 2               $71,800.00              $122,000.00
# 3               $62,400.00              $114,000.00
# ...

# %%
sikit = set(mergeddf2["NAME"].unique())
sikit
# Out:
# {'Amherst College',
#  'Appalachian State University',
#  'Arizona State University',
#  'Auburn University',
#  'Austin Peay State University',
#  'Ball State University',
#  'Bates College',
#  'Black Hills State University',
#  'Boise State University',
#  'Bowdoin College',
#  'Bowling Green State University',
#  'Brown University',
#  'Bucknell University',
#  'Buffalo State SUNY',
#  'California Institute of Technology',
#  'California Polytechnic State University-San Luis Obispo',
#  'California State University-Chico',
#  'California State University-Dominguez Hills',
#  'California State University-East Bay',
#  'California State University-Fullerton',
#  'California State University-Long Beach',
#  'California State University-Northridge',
#  'California State University-Sacramento',
#  'California State University-Stanislaus',
#  'Carleton College',
#  'Carnegie Mellon University',
#  'Clemson University',
#  'Cleveland State University',
#  'Colby College',
# ...

# %%
banyak = set(salaries["NAME"].unique())
banyak
# Out:
# {'Amherst College',
#  'Appalachian State University',
#  'Arizona State University',
#  'Arkansas State University',
#  'Auburn University',
#  'Austin Peay State University',
#  'Ball State University',
#  'Bates College',
#  'Binghamton University',
#  'Black Hills State University',
#  'Boise State University',
#  'Bowdoin College',
#  'Bowling Green State University',
#  'Brown University',
#  'Bucknell University',
#  'Buffalo State SUNY',
#  'California Institute of Technology',
#  'California Polytechnic State University-San Luis Obispo',
#  'California State University-Chico',
#  'California State University-Dominguez Hills',
#  'California State University-East Bay',
#  'California State University-Fullerton',
#  'California State University-Long Beach',
#  'California State University-Northridge',
#  'California State University-Sacramento',
#  'California State University-Stanislaus',
#  'Carleton College',
#  'Carnegie Mellon University',
#  'Clemson University',
# ...

# %%
banyak - sikit
# Out:
# {'Arkansas State University',
#  'Binghamton University',
#  'Louisiana State University',
#  'Texas A&M University',
#  'University of California, Santa Barbara',
#  'University of Hawaii',
#  'University of Maryland, College Park',
#  'University of Missouri-Rolla',
#  'University of Nebraska at Omaha',
#  'University of Texas at Austin'}

# %%
mergeddf2.to_csv("university_median_income_expected_income.csv", index = False)
